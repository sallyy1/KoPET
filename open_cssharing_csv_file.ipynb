# %%
#unlabeled_path = './laws/unlabeled.jsonl'
#logits_path = './Law_Output/g2/unlabeled_logits.txt'

unlabeled_path = './cssharing_new-BIG/unlabeled.jsonl'

import json

all_data = []

with open(unlabeled_path, 'r', encoding='utf-8') as f:
    cnt = 0
    for line in f:
        cnt += 1
        example_json = json.loads(line) # json.load: JSON 형태의 문자열을 dictionary 형태의 자료형으로 반환

#         idx = example_json['idx']
#         label = str(example_json['label']) if 'label' in example_json else None
#         text_a = example_json['text']
        
#         print(example_json['idx'], example_json['text'], label)
#         print('*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*')
#         all_data.append([example_json['idx'], example_json['text'], label])

print(cnt)
# Out:
# 1697139

# %%
import csv
import numpy as np

idx = -1


path = './cs_sharing_all_sentence.csv'


with open(path, 'r', encoding='utf-8') as f2:
    strings = f2.readlines()
    for line in strings:
        line = line.rstrip()
        print(line)
        
#         if line == '-1':
#             continue
            
#         idx += 1
#         print(line, type(line))
#         label_0, label_1 = line.split(' ')
#         label_0, label_1 = float(label_0), float(label_1)
#         result = np.array([label_0, label_1])
#         print(result)
#         predictions = np.argmax(result, axis=0)
#         print(predictions)
#         all_data[idx][2] = predictions # 예측한 label값으로 업데이트
#         print(all_data[idx])
#         print()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
for line in all_data:
    print(line)
# Out:
# [0, '펀드(집합투자기구)의 종류가 너무 많아서 어디에 투자를 해야 할지 모르겠습니다. 펀드의 종류에는 무엇이 있으며, 각각의 특징은 무엇인가요?', 1]
# [1, '국내 주식형 펀드에 투자했다가, 유럽재정 위기악화로 인하여 큰 손실을 입었습니다. 손해를 배상받고 싶은데요, 어떻게 해야 하나요?', 0]
# [2, '보험설계사로 일하는 중입니다. 보험계약에 대한 감사의 의미로 보험계약자에게 영화티켓 2장을 제공하려하는데, 괜찮을까요?', 1]
# [3, '가게가 어려워 은행에서 대출상담을 하던 중 특정 보험에 가입하면 대출조건을 완화하여 대출해 주겠다는 얘기를 들었습니다. 이렇게 해도 되는건가요?', 0]
# [4, '3년 2개월 전에 남편 앞으로 생명보험에 가입하고자 보험설계사를 불러 보험계약을 체결하였습니다. 그런데 보험 체결 전 남편이 간 기능 이상으로 저 몰래 병원치료를 받았다는 사실을 나중에 알게 되었지만, 이미 보험계약을 체결한 상태여서 말하지 않았습니다. 보름전 남편의 사망으로 사망보험금을 청구했으나 보험회사는 ‘계약 전 고지의무 위반’으로 보험금지급을 거절하고 있습니다.', 0]
# [5, '생애 최초로 중고차를 구입하여 명의이전과 함께 자동차종합보험에 가입하고, 1회보험료를 납부한 다음 드라이브를 나섰다가 사고가 났습니다. 누군가 자동차보험은 가입한 날 밤 12시부터 보험이 적용된다던데 사실인가요?', 0]
# [6, '신청인 A씨는 보험계약 청약 시 오토바이 운전을 하지 않는다고 청약서에 기재하였으나, 이후 B보험사에서 계약내용 확인을 위해 연락하자 A는 오토바이를 운전한다고 알렸고 일주일후 피신청인은 계약을 불승낙 처리하였습니다. 그런데 동 일주일 사이에 오토바이 사고가 발생하였다면 보험금을 청구할 수 있을까요?', 0]
# ...

# %%
new_f = open('./predict_labeled_data.csv', 'w')
wr = csv.writer(new_f)

wr.writerow(['idx', 'text', 'predicted label'])

for line in all_data:
    wr.writerow(line)

new_f.close()
